# 2000-02-11  24.420000  6973.399902
# 2000-02-14  24.379999  6921.700195
# ...               ...          ...
# 2017-03-08  11.860000  8626.700195
# 2017-03-09  12.300000  8639.700195
# 2017-03-10  11.660000  8670.000000
# 2017-03-13  11.350000  8683.099609
# 2017-03-14  12.300000  8663.500000
# 2017-03-15  11.630000  8688.900391
# 2017-03-16  11.210000  8667.500000
# 2017-03-17  11.280000  8698.500000
# 2017-03-20  11.340000  8695.000000
# 2017-03-21  12.470000  8614.900391
# 2017-03-22  12.810000  8567.900391
# 2017-03-23  13.120000  8628.599609
# 2017-03-24  12.960000  8613.599609
# 2017-03-27  12.500000  8594.500000
# 2017-03-28  11.530000  8597.000000
# 2017-03-29  11.420000  8661.500000
# 2017-03-30  11.540000  8704.400391
# 2017-03-31  12.370000  8658.900391
# 2017-04-03  12.380000  8633.900391
# 2017-04-04  11.790000  8647.000000
# 2017-04-05  12.890000  8640.500000
# 2017-04-06  12.390000  8638.400391
# 2017-04-07  12.870000  8640.900391
# 2017-04-10  14.050000  8616.700195
# 2017-04-11  15.070000  8641.599609
# 2017-04-12  15.770000  8663.799805
# 2017-04-13  15.960000  8629.000000
# 2017-04-17  14.660000          NaN
# 2017-04-18  14.420000  8529.299805
# 2017-04-19  14.930000  8532.299805
#
# [4351 rows x 7 columns]

# %%
import sympy
import numpy as np

# %%
a = sympy.symbols('a')
b = sympy.symbols('b')
c = sympy.symbols('c')

e = sympy.symbols('e')
f = sympy.symbols('f')
g = sympy.symbols('g')

x = np.matrix([a, b, c])
y = np.matrix([e, f, g])


# x*y.T
y*x.T
# Out:
# matrix([[a*e + b*f + c*g]], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
return_vec = np.random.randn(4, 1000)

# %%
plt.plot(return_vec.T, alpha=.3)
# Out:
# [<matplotlib.lines.Line2D at 0x7f46ce99d6a0>,
#  <matplotlib.lines.Line2D at 0x7f46ce99d898>,
#  <matplotlib.lines.Line2D at 0x7f46ce99d128>,
#  <matplotlib.lines.Line2D at 0x7f46ce99d518>]

# %%
def rand_weights(n):
    ''' Produces n random weights that sum to 1 '''
    k = np.random.rand(n)
    return k / sum(k)

# %%
def random_portfolio(returns):
    ''' 
    Returns the mean and standard deviation of returns for a random portfolio
    '''

    p = np.asmatrix(np.mean(returns, axis=1))
    w = np.asmatrix(rand_weights(returns.shape[0]))
    C = np.asmatrix(np.cov(returns))
    
    mu = w * p.T
    sigma = np.sqrt(w * C * w.T)
    
    # This recursion reduces outliers to keep plots pretty
    if sigma > 2:
        return random_portfolio(returns)
    return mu, sigma

# %%
n_portfolios = 5000
means, stds = np.column_stack([
    random_portfolio(return_vec) 
    for _ in range(n_portfolios)
])

# %%
plt.plot(stds, means, 'o', markersize=5)
plt.xlabel('std')
plt.ylabel('mean')
plt.title('Mean and standard deviation of returns of randomly generated portfolios');
